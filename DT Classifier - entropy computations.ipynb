# %%
# Importing the required packages 
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn import tree

# %%
# import Dataset 
import pandas as pd
df=pd.read_excel(r'C:\Users\ParsaRz\Desktop\introduction to machine learning- assignment 1\heart.xlsx')
print (df)
# Out:
#      sex  cp  fbs  restecg  exang  target
# 0      1   1    1        0      0       1
# 1      1   1    0        1      0       1
# 2      0   1    0        0      0       1
# 3      1   1    0        1      0       1
# 4      0   0    0        1      1       1
# ..   ...  ..  ...      ...    ...     ...
# 298    0   0    0        1      1       0
# 299    1   1    0        1      0       0
# 300    1   0    1        1      0       0
# 301    1   0    0        1      1       0
# 302    0   1    0        0      0       0
#
# [303 rows x 6 columns]

# %%
# Separating the target variable  
X=df[['sex' , 'cp' , 'fbs' , 'restecg' ,'exang']]
Y=df.target

# %%
# features of the data
featureNames=['sex' , 'cp' , 'fbs','restecg' ,'exang' ]
target_names=['0','1']

# %%
#builiding tree
# Fit the model  
model=clf_gini=DecisionTreeClassifier(criterion='entropy' , random_state=100 , max_depth=3 )
X=df[featureNames]
Y=df.target
model2=model.fit(X ,Y)

# %%
#better resolution
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (3,3), dpi=750)
tree.plot_tree(model, feature_names = featureNames, class_names=target_names, filled = True, impurity = True);
